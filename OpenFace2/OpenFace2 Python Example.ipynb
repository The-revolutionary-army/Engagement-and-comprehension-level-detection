# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import cv2
sys.path.append("C:/Users/Omar/Documents/GitHub/Comprehension-Level-Detection/OpenFace2")

# %%
import openface2
au_model=openface2.AUs("C:/Users/Omar/Documents/GitHub/Comprehension-Level-Detection/OpenFace2/model")

# %%
img = cv2.imread('C:/Users/Omar/template2.jpg')
img2 = cv2.imread('C:/Users/Omar/output.jpg')
img3 = cv2.imread('C:/Users/Omar/output2.jpg')
    
def plotImg(img):
    plt.figure()
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)

# %%
plotImg(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
au_model.predict(img3)
# Out:
# {'AU01': 0.0,
#  'AU02': 0.0,
#  'AU04': 0.0,
#  'AU05': 1.0,
#  'AU06': 1.0,
#  'AU07': 0.0,
#  'AU09': 0.0,
#  'AU10': 1.0,
#  'AU12': 1.0,
#  'AU14': 1.0,
#  'AU15': 0.0,
#  'AU17': 0.0,
#  'AU20': 0.0,
#  'AU23': 0.0,
#  'AU25': 0.0,
#  'AU26': 0.0,
#  'AU28': 0.0,
#  'AU45': 0.0}

# %%
plotImg(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
au_model.predict(img2)
# Out:
# {'AU01': 0.0,
#  'AU02': 0.0,
#  'AU04': 0.0,
#  'AU05': 1.0,
#  'AU06': 0.0,
#  'AU07': 0.0,
#  'AU09': 0.0,
#  'AU10': 0.0,
#  'AU12': 0.0,
#  'AU14': 0.0,
#  'AU15': 0.0,
#  'AU17': 0.0,
#  'AU20': 0.0,
#  'AU23': 0.0,
#  'AU25': 0.0,
#  'AU26': 0.0,
#  'AU28': 0.0,
#  'AU45': 0.0}

# %%
plotImg(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
au_model.predict(img)
# Out:
# {'AU01': 0.0,
#  'AU02': 0.0,
#  'AU04': 0.0,
#  'AU05': 0.0,
#  'AU06': 1.0,
#  'AU07': 1.0,
#  'AU09': 0.0,
#  'AU10': 1.0,
#  'AU12': 1.0,
#  'AU14': 1.0,
#  'AU15': 0.0,
#  'AU17': 0.0,
#  'AU20': 0.0,
#  'AU23': 1.0,
#  'AU25': 0.0,
#  'AU26': 0.0,
#  'AU28': 0.0,
#  'AU45': 0.0}
